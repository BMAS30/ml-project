# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yaml
import numpy as np
import sklearn

# %%
# import the dataset
with open('../config.yaml', 'r') as file:
    config = yaml.safe_load(file)
df = pd.read_csv(config["input_data"]["file_1"])

# %%
""" the idea: create a ml and predict obesity according to categorical columns using knn classifier, and same process with numerical columns using knn regressor"""
